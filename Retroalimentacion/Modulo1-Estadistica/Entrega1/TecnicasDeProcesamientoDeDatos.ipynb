# %% [markdown]
# # Momento de Retroalimentación: Módulo 1 Técnicas de procesamiento de datos para el análisis estadístico y para la construcción de modelos (Portafolio Análisis)
#
# Nombre: Marcelo Márquez Murillo
# Matricula: A01720588
#
# Una empresa automovilística china aspira a entrar en el mercado estadounidense. Desea establecer allí una unidad de fabricación y producir automóviles localmente para competir con sus contrapartes estadounidenses y europeas. Contrataron una empresa de consultoría de automóviles para identificar los principales factores de los que depende el precio de los automóviles, específicamente, en el mercado estadounidense, ya que pueden ser muy diferentes del mercado chino. Esencialmente, la empresa quiere saber:
# * Qué variables son significativas para predecir el precio de un automóvil
# * Qué tan bien describen esas variables el precio de un automóvil

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('precios_autos.csv')
df
# Out:
#      symboling                   CarName fueltype      carbody drivewheel  \
# 0            3        alfa-romero giulia      gas  convertible        rwd
# 1            3       alfa-romero stelvio      gas  convertible        rwd
# 2            1  alfa-romero Quadrifoglio      gas    hatchback        rwd
# 3            2               audi 100 ls      gas        sedan        fwd
# 4            2                audi 100ls      gas        sedan        4wd
# ..         ...                       ...      ...          ...        ...
# 200         -1           volvo 145e (sw)      gas        sedan        rwd
# 201         -1               volvo 144ea      gas        sedan        rwd
# 202         -1               volvo 244dl      gas        sedan        rwd
# 203         -1                 volvo 246   diesel        sedan        rwd
# 204         -1               volvo 264gl      gas        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# 0            front       88.6      168.8      64.1       48.8  ...
# 1            front       88.6      168.8      64.1       48.8  ...
# 2            front       94.5      171.2      65.5       52.4  ...
# 3            front       99.8      176.6      66.2       54.3  ...
# 4            front       99.4      176.6      66.4       54.3  ...
# ..             ...        ...        ...       ...        ...  ...
# 200          front      109.1      188.8      68.9       55.5  ...
# 201          front      109.1      188.8      68.8       55.5  ...
# 202          front      109.1      188.8      68.9       55.5  ...
# 203          front      109.1      188.8      68.9       55.5  ...
# 204          front      109.1      188.8      68.9       55.5  ...
#
#      enginetype cylindernumber enginesize  stroke  compressionratio  \
# 0          dohc           four        130    2.68               9.0
# 1          dohc           four        130    2.68               9.0
# 2          ohcv            six        152    3.47               9.0
# 3           ohc           four        109    3.40              10.0
# 4           ohc           five        136    3.40               8.0
# ..          ...            ...        ...     ...               ...
# 200         ohc           four        141    3.15               9.5
# 201         ohc           four        141    3.15               8.7
# 202        ohcv            six        173    2.87               8.8
# 203         ohc            six        145    3.40              23.0
# 204         ohc           four        141    3.15               9.5
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 0           111     5000       21          27  13495.0
# 1           111     5000       21          27  16500.0
# 2           154     5000       19          26  16500.0
# 3           102     5500       24          30  13950.0
# 4           115     5500       18          22  17450.0
# ..          ...      ...      ...         ...      ...
# 200         114     5400       23          28  16845.0
# 201         160     5300       19          25  19045.0
# 202         134     5500       18          23  21485.0
# 203         106     4800       26          27  22470.0
# 204         114     5400       19          25  22625.0
#
# [205 rows x 21 columns]

# %% [markdown]
# ## Exploración de la base de datos

# %% [markdown]
# ### 1. Calcula medidas estadísticas apropiadas para las variables cuantitativas (media, desviación estándar, cuantiles, etc.) y para las cualitativas (cuantiles, frecuencias)

# %%
# Variables cuantitativas
quantitative_columns = ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']
quantitative_df = df[quantitative_columns]
quantitative_df.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginesize      stroke  compressionratio  horsepower      peakrpm  \
# count  205.000000  205.000000        205.000000  205.000000   205.000000
# mean   126.907317    3.255415         10.142537  104.117073  5125.121951
# std     41.642693    0.313597          3.972040   39.544167   476.985643
# min     61.000000    2.070000          7.000000   48.000000  4150.000000
# 25%     97.000000    3.110000          8.600000   70.000000  4800.000000
# 50%    120.000000    3.290000          9.000000   95.000000  5200.000000
# 75%    141.000000    3.410000          9.400000  116.000000  5500.000000
# max    326.000000    4.170000         23.000000  288.000000  6600.000000
#
#           citympg  highwaympg         price
# count  205.000000  205.000000    205.000000
# mean    25.219512   30.751220  13276.710571
# std      6.542142    6.886443   7988.852332
# min     13.000000   16.000000   5118.000000
# 25%     19.000000   25.000000   7788.000000
# 50%     24.000000   30.000000  10295.000000
# 75%     30.000000   34.000000  16503.000000
# max     49.000000   54.000000  45400.000000

# %%
# Variables categóricas
categorical_columns = ['symboling', 'CarName', 'fueltype', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber']
categorical_df = df[categorical_columns]
categorical_df
# Out:
#      symboling                   CarName fueltype      carbody drivewheel  \
# 0            3        alfa-romero giulia      gas  convertible        rwd
# 1            3       alfa-romero stelvio      gas  convertible        rwd
# 2            1  alfa-romero Quadrifoglio      gas    hatchback        rwd
# 3            2               audi 100 ls      gas        sedan        fwd
# 4            2                audi 100ls      gas        sedan        4wd
# ..         ...                       ...      ...          ...        ...
# 200         -1           volvo 145e (sw)      gas        sedan        rwd
# 201         -1               volvo 144ea      gas        sedan        rwd
# 202         -1               volvo 244dl      gas        sedan        rwd
# 203         -1                 volvo 246   diesel        sedan        rwd
# 204         -1               volvo 264gl      gas        sedan        rwd
#
#     enginelocation enginetype cylindernumber
# 0            front       dohc           four
# 1            front       dohc           four
# 2            front       ohcv            six
# 3            front        ohc           four
# 4            front        ohc           five
# ..             ...        ...            ...
# 200          front        ohc           four
# 201          front        ohc           four
# 202          front       ohcv            six
# 203          front        ohc            six
# 204          front        ohc           four
#
# [205 rows x 8 columns]

# %% [markdown]
# ### 2. Explora los datos usando herramientas de visualización:

# %% [markdown]
# * Variables cuantitativas:
#     - Medidas de posición: cuartiles, outlier (valores atípicos), boxplots
#     - Análisis de distribución de los datos (Histogramas). Identificar si tiene forma simétrica o asimétrica
#     - Analiza colinealidad (coeficiente de correlación y diagramas de dispersión)

# %%
# Medidas de posición
for column in quantitative_df.columns:
    box = plt.boxplot(quantitative_df[column])
    plt.title(f'Boxplot de {column}')
    plt.ylabel('Valores')

    plt.xticks([1], [column])
    plt.show()

# %%
# Histogramas de los datos
for column in quantitative_df.columns:
    plt.hist(quantitative_df[column], bins=15, color='skyblue',
             edgecolor='black')  # Adjust the number of bins as needed
    plt.title(f'Histograma de {column}')
    plt.xlabel(column)
    plt.ylabel('Frecuencia')
    plt.grid(axis='y', linestyle='--', alpha=1.0)
    # Conseguir la mediana de los datos
    median = quantitative_df[column].median()
    plt.axvline(median, color='green', linestyle='dashed', linewidth=2, label='Median')
    plt.show()

# %% [markdown]
# A partir de las gráficas se puede observar que as variables que tienen un comportamiento simétrico son carlength, carheight y peakrpm.

# %%
# Analiza colinealidad
plt.figure(figsize=(10, 6))
sns.heatmap(quantitative_df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Heatmap de correlación')
plt.show()

# %% [markdown]
# Se puede observar del diagrama de correlación lo siguiente:
# * La variable citympg y highway mpg tienen una correlación de 0.97 lo cual se aproxima a 1 por lo que se considera que ambas tienen colinealidad
# * La variable highway mpg tiene una corrlación negativa y alta en relación con price por lo que puede ser una muy buena variable para el modelo
# * Bajo la misma observación se puede considerar que las variables enginesize, horsepower, wheelbase, carlength y carwidth pueden ser variables que ayuden a explicar el comportamiento de la variable price con base en su coeficiente de correlación.

# %% [markdown]
# * Variables categóricas
#         - Distribución de los datos (diagramas de barras, diagramas de pastel)
#         - Analiza asociación o colinealidad (diagramas de caja y bigote de precio por categoría y barras por categoría)

# %%
# Distribución de los datos

for column in categorical_df.columns:
    selected_column = categorical_df[column].value_counts()
    labels = selected_column.index
    counts = selected_column.values
    plt.bar(labels, counts)
    plt.title(f"Diagrama de barra de {column}")
    plt.xlabel(column)
    plt.ylabel('Frecuencia')
    plt.grid(axis='y', linestyle='--', alpha=1.0)
    plt.show()

# %%
# Analiza asociación
for column in categorical_df.columns:
    plt.title(f"Boxplot de {column}")
    sns.boxplot(x=column, y="price", data=df)
    plt.show()

# %% [markdown]
# ### 3. Identifica problemas de calidad de datos (valores faltantes, outliers, etc).

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# No hay valores faltantes
# Out:
# symboling           0
# CarName             0
# fueltype            0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
for column in quantitative_df:
    # Conseguimos cuantil 1 y cuantil 3 
    Q1 = quantitative_df[column].quantile(0.25)
    Q3 = quantitative_df[column].quantile(0.75)
    #  Se consigue el rango intercuantil
    IQR = Q3 - Q1
    # mostramos todos los datos atípicos
    df_outliers = quantitative_df[
        ~((quantitative_df[column] >= (Q1 - 1.5 * IQR)) & (quantitative_df[column] <= (Q3 + 1.5 * IQR)))]
    print(f"Outliers de columna {column}: {df_outliers}")
# Out:
# Outliers de columna wheelbase:     wheelbase  carlength  carwidth  carheight  curbweight  enginesize  stroke  \
# 70      115.6      202.6      71.7       56.3        3770         183    3.64
# 71      115.6      202.6      71.7       56.5        3740         234    3.10
# 73      120.9      208.1      71.7       56.7        3900         308    3.35
#
#     compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 70              21.5         123     4350       22          25  31600.0
# 71               8.3         155     4750       16          18  34184.0
# 73               8.0         184     4500       14          16  40960.0
# Outliers de columna carlength:     wheelbase  carlength  carwidth  carheight  curbweight  enginesize  stroke  \
# 18       88.4      141.1      60.3       53.2        1488          61    3.03
#
#     compressionratio  horsepower  peakrpm  citympg  highwaympg   price
# 18               9.5          48     5100       47          53  5151.0
# Outliers de columna carwidth:      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 6        105.8      192.7      71.4       55.7        2844         136
# 7        105.8      192.7      71.4       55.7        2954         136
# 8        105.8      192.7      71.4       55.9        3086         131
# 70       115.6      202.6      71.7       56.3        3770         183
# 71       115.6      202.6      71.7       56.5        3740         234
# 73       120.9      208.1      71.7       56.7        3900         308
# 74       112.0      199.2      72.0       55.4        3715         304
# 129       98.4      175.7      72.3       50.5        3366         203
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 6      3.40               8.5         110     5500       19          25
# 7      3.40               8.5         110     5500       19          25
# 8      3.40               8.3         140     5500       17          20
# 70     3.64              21.5         123     4350       22          25
# 71     3.10               8.3         155     4750       16          18
# 73     3.35               8.0         184     4500       14          16
# 74     3.35               8.0         184     4500       14          16
# 129    3.11              10.0         288     5750       17          28
#
#        price
# 6    17710.0
# 7    18920.0
# 8    23875.0
# 70   31600.0
# 71   34184.0
# 73   40960.0
# 74   45400.0
# 129  31400.5
# Outliers de columna carheight: Empty DataFrame
# Columns: [wheelbase, carlength, carwidth, carheight, curbweight, enginesize, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
# Outliers de columna curbweight: Empty DataFrame
# Columns: [wheelbase, carlength, carwidth, carheight, curbweight, enginesize, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
# Outliers de columna enginesize:     wheelbase  carlength  carwidth  carheight  curbweight  enginesize  stroke  \
# 15      103.5      189.0      66.9       55.7        3230         209    3.39
# 16      103.5      193.8      67.9       53.7        3380         209    3.39
# 17      110.0      197.0      70.9       56.3        3505         209    3.39
# 47      113.0      199.6      69.6       52.8        4066         258    4.17
# 48      113.0      199.6      69.6       52.8        4066         258    4.17
# 49      102.0      191.7      70.6       47.8        3950         326    2.76
# 71      115.6      202.6      71.7       56.5        3740         234    3.10
# 72       96.6      180.3      70.5       50.8        3685         234    3.10
# 73      120.9      208.1      71.7       56.7        3900         308    3.35
# 74      112.0      199.2      72.0       55.4        3715         304    3.35
#
#     compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 15               8.0         182     5400       16          22  30760.0
# 16               8.0         182     5400       16          22  41315.0
# 17               8.0         182     5400       15          20  36880.0
# 47               8.1         176     4750       15          19  32250.0
# 48               8.1         176     4750       15          19  35550.0
# 49              11.5         262     5000       13          17  36000.0
# 71               8.3         155     4750       16          18  34184.0
# 72               8.3         155     4750       16          18  35056.0
# 73               8.0         184     4500       14          16  40960.0
# 74               8.0         184     4500       14          16  45400.0
# Outliers de columna stroke:      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 29        95.9      173.2      66.3       50.2        2811         156
# 47       113.0      199.6      69.6       52.8        4066         258
# 48       113.0      199.6      69.6       52.8        4066         258
# 111      107.9      186.7      68.4       56.7        3075         120
# 113      114.2      198.9      68.4       56.7        3285         120
# 130       96.1      181.5      66.5       55.2        2579         132
# 131       96.1      176.8      66.6       50.5        2460         132
# 134       99.1      186.6      66.5       56.1        2707         121
# 138       93.7      156.9      63.4       53.7        2050          97
# 139       93.7      157.9      63.6       53.7        2120         108
# 140       93.3      157.3      63.8       55.7        2240         108
# 141       97.2      172.0      65.4       52.5        2145         108
# 142       97.2      172.0      65.4       52.5        2190         108
# 143       97.2      172.0      65.4       52.5        2340         108
# 144       97.0      172.0      65.4       54.3        2385         108
# 145       97.0      172.0      65.4       54.3        2510         108
# 146       97.0      173.5      65.4       53.0        2290         108
# 147       97.0      173.5      65.4       53.0        2455         108
# 148       96.9      173.6      65.4       54.9        2420         108
# 149       96.9      173.6      65.4       54.9        2650         108
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 29     3.90               7.0         145     5000       19          24
# 47     4.17               8.1         176     4750       15          19
# 48     4.17               8.1         176     4750       15          19
# 111    2.19               8.4          95     5000       19          24
# 113    2.19               8.4          95     5000       19          24
# 130    3.90               8.7          90     5100       23          31
# 131    3.90               8.7          90     5100       23          31
# 134    2.07               9.3         110     5250       21          28
# 138    2.36               9.0          69     4900       31          36
# 139    2.64               8.7          73     4400       26          31
# 140    2.64               8.7          73     4400       26          31
# 141    2.64               9.5          82     4800       32          37
# 142    2.64               9.5          82     4400       28          33
# 143    2.64               9.0          94     5200       26          32
# 144    2.64               9.0          82     4800       24          25
# 145    2.64               7.7         111     4800       24          29
# 146    2.64               9.0          82     4800       28          32
# 147    2.64               9.0          94     5200       25          31
# 148    2.64               9.0          82     4800       23          29
# 149    2.64               7.7         111     4800       23          23
#
#        price
# 29   12964.0
# 47   32250.0
# 48   35550.0
# 111  15580.0
# 113  16695.0
# 130   9295.0
# 131   9895.0
# 134  15040.0
# 138   5118.0
# 139   7053.0
# 140   7603.0
# 141   7126.0
# 142   7775.0
# 143   9960.0
# 144   9233.0
# 145  11259.0
# 146   7463.0
# 147  10198.0
# 148   8013.0
# 149  11694.0
# Outliers de columna compressionratio:      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 9         99.5      178.2      67.9       52.0        3053         131
# 29        95.9      173.2      66.3       50.2        2811         156
# 49       102.0      191.7      70.6       47.8        3950         326
# 63        98.8      177.8      66.5       55.5        2443         122
# 66       104.9      175.0      66.1       54.4        2700         134
# 67       110.0      190.9      70.3       56.5        3515         183
# 68       110.0      190.9      70.3       58.7        3750         183
# 69       106.7      187.5      70.3       54.9        3495         183
# 70       115.6      202.6      71.7       56.3        3770         183
# 82        95.9      173.2      66.3       50.2        2833         156
# 83        95.9      173.2      66.3       50.2        2921         156
# 84        95.9      173.2      66.3       50.2        2926         156
# 90        94.5      165.3      63.8       54.5        2017         103
# 108      107.9      186.7      68.4       56.7        3197         152
# 110      114.2      198.9      68.4       58.7        3430         152
# 112      107.9      186.7      68.4       56.7        3252         152
# 114      114.2      198.9      68.4       58.7        3485         152
# 116      107.9      186.7      68.4       56.7        3252         152
# 117      108.0      186.7      68.3       56.0        3130         134
# 124       95.9      173.2      66.3       50.2        2818         156
# 158       95.7      166.3      64.4       53.0        2275         110
# 159       95.7      166.3      64.4       52.8        2275         110
# 174      102.4      175.6      66.5       54.9        2480         110
# 182       97.3      171.7      65.5       55.7        2261          97
# 184       97.3      171.7      65.5       55.7        2264          97
# 187       97.3      171.7      65.5       55.7        2319          97
# 192      100.4      180.2      66.9       55.1        2579          97
# 203      109.1      188.8      68.9       55.5        3217         145
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 9      3.40               7.0         160     5500       16          22
# 29     3.90               7.0         145     5000       19          24
# 49     2.76              11.5         262     5000       13          17
# 63     3.39              22.7          64     4650       36          42
# 66     3.64              22.0          72     4200       31          39
# 67     3.64              21.5         123     4350       22          25
# 68     3.64              21.5         123     4350       22          25
# 69     3.64              21.5         123     4350       22          25
# 70     3.64              21.5         123     4350       22          25
# 82     3.86               7.0         145     5000       19          24
# 83     3.86               7.0         145     5000       19          24
# 84     3.86               7.0         145     5000       19          24
# 90     3.47              21.9          55     4800       45          50
# 108    3.52              21.0          95     4150       28          33
# 110    3.52              21.0          95     4150       25          25
# 112    3.52              21.0          95     4150       28          33
# 114    3.52              21.0          95     4150       25          25
# 116    3.52              21.0          95     4150       28          33
# 117    3.21               7.0         142     5600       18          24
# 124    3.86               7.0         145     5000       19          24
# 158    3.35              22.5          56     4500       34          36
# 159    3.35              22.5          56     4500       38          47
# 174    3.35              22.5          73     4500       30          33
# 182    3.40              23.0          52     4800       37          46
# 184    3.40              23.0          52     4800       37          46
# 187    3.40              23.0          68     4500       37          42
# 192    3.40              23.0          68     4500       33          38
# 203    3.40              23.0         106     4800       26          27
#
#          price
# 9    17859.167
# 29   12964.000
# 49   36000.000
# 63   10795.000
# 66   18344.000
# 67   25552.000
# 68   28248.000
# 69   28176.000
# 70   31600.000
# 82   12629.000
# 83   14869.000
# 84   14489.000
# 90    7099.000
# 108  13200.000
# 110  13860.000
# 112  16900.000
# 114  17075.000
# 116  17950.000
# 117  18150.000
# 124  12764.000
# 158   7898.000
# 159   7788.000
# 174  10698.000
# 182   7775.000
# 184   7995.000
# 187   9495.000
# 192  13845.000
# 203  22470.000
# Outliers de columna horsepower:      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 49       102.0      191.7      70.6       47.8        3950         326
# 105       91.3      170.7      67.9       49.7        3139         181
# 126       89.5      168.9      65.0       51.6        2756         194
# 127       89.5      168.9      65.0       51.6        2756         194
# 128       89.5      168.9      65.0       51.6        2800         194
# 129       98.4      175.7      72.3       50.5        3366         203
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 49     2.76              11.5         262     5000       13          17
# 105    3.27               7.8         200     5200       17          23
# 126    2.90               9.5         207     5900       17          25
# 127    2.90               9.5         207     5900       17          25
# 128    2.90               9.5         207     5900       17          25
# 129    3.11              10.0         288     5750       17          28
#
#        price
# 49   36000.0
# 105  19699.0
# 126  32528.0
# 127  34028.0
# 128  37028.0
# 129  31400.5
# Outliers de columna peakrpm:      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 165       94.5      168.7      64.0       52.6        2265          98
# 166       94.5      168.7      64.0       52.6        2300          98
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 165    3.08               9.4         112     6600       26          29
# 166    3.08               9.4         112     6600       26          29
#
#       price
# 165  9298.0
# 166  9538.0
# Outliers de columna citympg:     wheelbase  carlength  carwidth  carheight  curbweight  enginesize  stroke  \
# 18       88.4      141.1      60.3       53.2        1488          61    3.03
# 30       86.6      144.6      63.9       50.8        1713          92    3.41
#
#     compressionratio  horsepower  peakrpm  citympg  highwaympg   price
# 18               9.5          48     5100       47          53  5151.0
# 30               9.6          58     4800       49          54  6479.0
# Outliers de columna highwaympg:     wheelbase  carlength  carwidth  carheight  curbweight  enginesize  stroke  \
# 18       88.4      141.1      60.3       53.2        1488          61    3.03
# 30       86.6      144.6      63.9       50.8        1713          92    3.41
# 90       94.5      165.3      63.8       54.5        2017         103    3.47
#
#     compressionratio  horsepower  peakrpm  citympg  highwaympg   price
# 18               9.5          48     5100       47          53  5151.0
# 30               9.6          58     4800       49          54  6479.0
# 90              21.9          55     4800       45          50  7099.0
# Outliers de columna price:      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 15       103.5      189.0      66.9       55.7        3230         209
# 16       103.5      193.8      67.9       53.7        3380         209
# 17       110.0      197.0      70.9       56.3        3505         209
# 47       113.0      199.6      69.6       52.8        4066         258
# 48       113.0      199.6      69.6       52.8        4066         258
# 49       102.0      191.7      70.6       47.8        3950         326
# 70       115.6      202.6      71.7       56.3        3770         183
# 71       115.6      202.6      71.7       56.5        3740         234
# 72        96.6      180.3      70.5       50.8        3685         234
# 73       120.9      208.1      71.7       56.7        3900         308
# 74       112.0      199.2      72.0       55.4        3715         304
# 126       89.5      168.9      65.0       51.6        2756         194
# 127       89.5      168.9      65.0       51.6        2756         194
# 128       89.5      168.9      65.0       51.6        2800         194
# 129       98.4      175.7      72.3       50.5        3366         203
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 15     3.39               8.0         182     5400       16          22
# 16     3.39               8.0         182     5400       16          22
# 17     3.39               8.0         182     5400       15          20
# 47     4.17               8.1         176     4750       15          19
# 48     4.17               8.1         176     4750       15          19
# 49     2.76              11.5         262     5000       13          17
# 70     3.64              21.5         123     4350       22          25
# 71     3.10               8.3         155     4750       16          18
# 72     3.10               8.3         155     4750       16          18
# 73     3.35               8.0         184     4500       14          16
# 74     3.35               8.0         184     4500       14          16
# 126    2.90               9.5         207     5900       17          25
# 127    2.90               9.5         207     5900       17          25
# 128    2.90               9.5         207     5900       17          25
# 129    3.11              10.0         288     5750       17          28
#
#        price
# 15   30760.0
# 16   41315.0
# 17   36880.0
# 47   32250.0
# 48   35550.0
# 49   36000.0
# 70   31600.0
# 71   34184.0
# 72   35056.0
# 73   40960.0
# 74   45400.0
# 126  32528.0
# 127  34028.0
# 128  37028.0
# 129  31400.5

# %% [markdown]
# ### 4. Con base en este análisis selecciona al menos 6 variables que consideres importantes para el análisis de las características de los automóviles que determinan su precio.

# %%
# Seleccionando columnas para el modelo
selected_columns = ["cylindernumber", "enginesize", "horsepower", "highwaympg", "carwidth", "curbweight", "price"]
selected_df = df[selected_columns]
selected_df
# Out:
#     cylindernumber  enginesize  horsepower  highwaympg  carwidth  curbweight  \
# 0             four         130         111          27      64.1        2548
# 1             four         130         111          27      64.1        2548
# 2              six         152         154          26      65.5        2823
# 3             four         109         102          30      66.2        2337
# 4             five         136         115          22      66.4        2824
# ..             ...         ...         ...         ...       ...         ...
# 200           four         141         114          28      68.9        2952
# 201           four         141         160          25      68.8        3049
# 202            six         173         134          23      68.9        3012
# 203            six         145         106          27      68.9        3217
# 204           four         141         114          25      68.9        3062
#
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 7 columns]

# %% [markdown]
# ## Preparación de la base de datos

# %% [markdown]
# ### 1. Selecciona el conjunto de datos a utilizar:

# %% [markdown]
# * Maneja datos categóricos: transforma variables dummy si es necesario.
# * Maneja apropiadamente datos atípicos.

# %%
# Transformación de variables categóricas de columna "Cylinder Number" a datos dummy
word_to_num = {
    'zero': 0,
    'one': 1,
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'seven': 7,
    'eight': 8,
    'nine': 9,
    'ten': 10,
    'eleven': 11,
    'twelve': 12,
}
# Reemplazando los valores por dummies
selected_df["cylindernumber"] = selected_df["cylindernumber"].replace(word_to_num)

selected_df.to_csv("precios_autos_fixed.csv", index=False)

selected_df.head(5)
# Out:
#    cylindernumber  enginesize  horsepower  highwaympg  carwidth  curbweight  \
# 0               4         130         111          27      64.1        2548
# 1               4         130         111          27      64.1        2548
# 2               6         152         154          26      65.5        2823
# 3               4         109         102          30      66.2        2337
# 4               5         136         115          22      66.4        2824
#
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0

# %% [markdown]
# ## Conclusión
#
# El análisis que se realizó me permitió observar cual es el comportamiento de los datos tanto numéricos como categóricos.
# A partir de esta información pude realizar una limpieza de los datos de manera que se pudiera tener una mejor fuente de información para realizar un modelo en próximas etapas de este proyecto.
#
# Durante este análisis se utilizaron métodos de imputación y de estadística descriptiva. Se utilizó el rango intercuartil, por ejemplo, para ver si existían valores atípicos al igual que un mapa de calor para evaluar la correlación entre las variables y determinar si existirían problemas de colinealidad en los datos.
#
# Además, se diseñaron una serie de gráficas que nos ayudan a visualizar cómo se distribuyen los datos, examinar cuál es la distribución de los mismos y determinar si existen valores atípicos de manera visual.
#
# Los métodos implementados en este análisis sirven como un gran fundamento para poder progresar y diseñar un modelo predictivo del precio de los carros.
